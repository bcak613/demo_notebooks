# %%
import requests

cookies = {
    'pmpro_visit': '1',
    '_ga': 'GA1.2.811184997.1665643978',
    '_gid': 'GA1.2.91859679.1665643978',
    '_gat_gtag_UA_33377407_1': '1',
}

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    # Requests sorts cookies= alphabetically
    # 'Cookie': 'pmpro_visit=1; _ga=GA1.2.811184997.1665643978; _gid=GA1.2.91859679.1665643978; _gat_gtag_UA_33377407_1=1',
    'Origin': 'https://div12.org',
    'Referer': 'https://div12.org/case-studies/?fbclid=IwAR3VboEbMnYTmb2U0B7ofEMiauurV0UMgSdtzZHtzAPScH_QSEy5nESzEio',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.37',
    'sec-ch-ua': '"Chromium";v="106", "Microsoft Edge";v="106", "Not;A=Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'fbclid': 'IwAR3VboEbMnYTmb2U0B7ofEMiauurV0UMgSdtzZHtzAPScH_QSEy5nESzEio',
}

data = {
    'symptoms[]': [
        'Irritability',
        'Loss of Interest',
        'Mania/Hypomania'
    ],
    'ak_bib': '',
    'ak_bfs': '1665644010897',
    'ak_bkpc': '0',
    'ak_bkp': '',
    'ak_bmc': '136;164,12597;',
    'ak_bmcc': '2',
    'ak_bmk': '',
    'ak_bck': '',
    'ak_bmmc': '6',
    'ak_btmc': '0',
    'ak_bsc': '4',
    'ak_bte': '',
    'ak_btec': '0',
    'ak_bmm': '741,383;68,212;98,13;1016,585;2429,1003;686,1954;',
}

response = requests.post('https://div12.org/case-studies/', params=params, cookies=cookies, headers=headers, data=data)

# %%
from IPython.display import display, HTML, Javascript
(response.text)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="en-US"
# 	prefix="og: https://ogp.me/ns#" >
#
# <head>
#
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <link rel="pingback" href="https://div12.org/xmlrpc.php">
# <title>Case Studies | Society of Clinical Psychology</title>
#
# 		<!-- All in One SEO 4.2.6.1 - aioseo.com -->
# 		<meta name="robots" content="max-image-preview:large" />
# 		<link rel="canonical" href="https://div12.org/case-studies/" />
# 		<meta name="generator" content="All in One SEO (AIOSEO) 4.2.6.1 " />
# 		<meta property="og:locale" content="en_US" />
# 		<meta property="og:site_name" content="Society of Clinical Psychology | Division 12 of the American Psychological Association" />
# 		<meta property="og:type" content="website" />
# 		<meta property="og:title" content="Case Studies | Society of Clinical Psychology" />
# 		<meta property="og:url" content="https://div12.org/case-studies/" />
# ...

# %%
from bs4 import BeautifulSoup as bs
soup = bs(response.content)

# %%
print(bs(main.content).prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://div12.org/xmlrpc.php" rel="pingback"/>
#   <title>
#    Case Studies | Society of Clinical Psychology
#   </title>
#   <!-- All in One SEO 4.2.6.1 - aioseo.com -->
#   <meta content="max-image-preview:large" name="robots"/>
#   <link href="https://div12.org/case-studies/" rel="canonical"/>
#   <meta content="All in One SEO (AIOSEO) 4.2.6.1 " name="generator"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="Society of Clinical Psychology | Division 12 of the American Psychological Association" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Case Studies | Society of Clinical Psychology" property="og:title"/>
#   <meta content="https://div12.org/case-studies/" property="og:url"/>
# ...

# %%
for link in soup.find_all('a'):
    if link.get('target') == '_blank':
        print(link.get('href'))
        print(link.text)
# Out:
# https://www.div12.org/?post_type=case_study&p=8426
# Albert (borderline personality disorder with co-morbid alcohol use)
# https://div12.org/?post_type=case_study&p=12589
# Danny (psychotic disorder)
# https://www.div12.org/?post_type=case_study&p=8441
# Gary (bipolar disorder)
# https://www.div12.org/?post_type=case_study&p=8419
# Jeff (alcohol use disorder, mild/moderate)
# https://div12.org/?post_type=case_study&p=12576
# Juan (alcohol use disorder)
# https://www.div12.org/?post_type=case_study&p=8431
# Phil (generalized anxiety disorder)
# https://www.div12.org/?post_type=case_study&p=8445
# Richard (bipolar disorder, substance use disorder)
# https://www.div12.org/?post_type=case_study&p=8443
# Sarah (bipolar disorder)
# https://www.div12.org/?post_type=case_study&p=8302
# Victor (post-traumatic stress disorder)

# %%
main = requests.get('https://div12.org/case-studies/')

# %%
for link in soup_main.find_all('input'):
    if link.get('name') == 'symptoms[]':
        print(link.get('value'))
#         print(link.text)
# Out:
# Agoraphobia
# Alcohol Use
# Anger
# Anxiety
# Binges and Purging
# Body Image
# Chronic Pain
# Compulsions
# Concentration Difficulties
# Delusions
# Depression
# Disordered Eating
# Elevated Mood
# Emotion Dysregulation
# Guilt
# Hallucinations
# Hypervigilance
# Impulsivity
# Intrusive Thoughts
# Irritability
# Loss of Interest
# Mania/Hypomania
# Mood Cycles
# Obesity/Overweight
# Obsessions
# Panic
# Psychosis
# Risky Behaviors
# Ruminations
# Self-Injury
# Sleep Difficulties
# Social Anxiety
# Substance Abuse
# Suicidal thoughts
# Trauma
# Worry

# %%
soup_main = bs(main.content)

# %%
print(bs(main.content).prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://div12.org/xmlrpc.php" rel="pingback"/>
#   <title>
#    Case Studies | Society of Clinical Psychology
#   </title>
#   <!-- All in One SEO 4.2.6.1 - aioseo.com -->
#   <meta content="max-image-preview:large" name="robots"/>
#   <link href="https://div12.org/case-studies/" rel="canonical"/>
#   <meta content="All in One SEO (AIOSEO) 4.2.6.1 " name="generator"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="Society of Clinical Psychology | Division 12 of the American Psychological Association" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Case Studies | Society of Clinical Psychology" property="og:title"/>
#   <meta content="https://div12.org/case-studies/" property="og:url"/>
# ...

# %%
def get_result(symptoms_list=[]):
    cookies = {
        'pmpro_visit': '1',
        '_ga': 'GA1.2.811184997.1665643978',
        '_gid': 'GA1.2.91859679.1665643978',
        '_gat_gtag_UA_33377407_1': '1',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Language': 'en-US,en;q=0.9,vi;q=0.8',
        'Cache-Control': 'max-age=0',
        'Connection': 'keep-alive',
        # Requests sorts cookies= alphabetically
        # 'Cookie': 'pmpro_visit=1; _ga=GA1.2.811184997.1665643978; _gid=GA1.2.91859679.1665643978; _gat_gtag_UA_33377407_1=1',
        'Origin': 'https://div12.org',
        'Referer': 'https://div12.org/case-studies/?fbclid=IwAR3VboEbMnYTmb2U0B7ofEMiauurV0UMgSdtzZHtzAPScH_QSEy5nESzEio',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.37',
        'sec-ch-ua': '"Chromium";v="106", "Microsoft Edge";v="106", "Not;A=Brand";v="99"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'fbclid': 'IwAR3VboEbMnYTmb2U0B7ofEMiauurV0UMgSdtzZHtzAPScH_QSEy5nESzEio',
    }

    data = {
        'symptoms[]': symptoms_list,
        'ak_bib': '',
        'ak_bfs': '1665644010897',
        'ak_bkpc': '0',
        'ak_bkp': '',
        'ak_bmc': '136;164,12597;',
        'ak_bmcc': '2',
        'ak_bmk': '',
        'ak_bck': '',
        'ak_bmmc': '6',
        'ak_btmc': '0',
        'ak_bsc': '4',
        'ak_bte': '',
        'ak_btec': '0',
        'ak_bmm': '741,383;68,212;98,13;1016,585;2429,1003;686,1954;',
    }

    response = requests.post('https://div12.org/case-studies/', params=params, cookies=cookies, headers=headers, data=data)
    
    soup = bs(response.content)
    
    i=0
    for link in soup.find_all('a'):
        if link.get('target') == '_blank':
            i = i+1
            print(str(i)+'. '+link.get('href'))
            print(link.text)

# %%
demo_list = [
    'Self-Injury',
    'Suicidal thoughts',
    'Trauma',
    'Worry',
    'Concentration Difficulties'
]

# %%
get_result(demo_list)
# Out:
# 1. https://www.div12.org/?post_type=case_study&p=8426
# Albert (borderline personality disorder with co-morbid alcohol use)
# 2. https://www.div12.org/?post_type=case_study&p=9680
# Dave (panic disorder)
# 3. https://www.div12.org/?post_type=case_study&p=9263
# Jen (attention-deficit/hyperactivity disorder)
# 4. https://div12.org/?post_type=case_study&p=12562
# John (obsessive-compulsive disorder)
# 5. https://www.div12.org/?post_type=case_study&p=8433
# Maria (binge eating disorder)
# 6. https://www.div12.org/?post_type=case_study&p=8424
# Mary (borderline personality disorder)
# 7. https://www.div12.org/?post_type=case_study&p=8431
# Phil (generalized anxiety disorder)
# 8. https://www.div12.org/?post_type=case_study&p=8302
# Victor (post-traumatic stress disorder)
